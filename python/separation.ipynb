# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import motion.detection as md
import man_vs_zone.clean as clean
project_dir = "../data/"

# %%
games = pd.read_csv(f'{project_dir}games.csv')
play_df = pd.read_csv(f'{project_dir}plays.csv')
player_plays = pd.read_csv(f'{project_dir}player_play.csv')
players = pd.read_csv(f'{project_dir}players.csv')
tracking_df = pd.read_csv(f'{project_dir}tracking_week_1.csv')

# %%
gid = 2022091104
pid = 3662

import animate
animate.animate_play(games, tracking_df, play_df, players, gid, pid)

# %%
players = clean.get_postion_groups(players)

cleaned_tracking = clean.flip_coords(tracking_df)

games = tracking_df['gameId'].unique()
play_df = play_df[play_df['gameId'].isin(games)]

play_df = play_df[play_df['pff_manZone'] != 'other']
tracking_df = tracking_df[(tracking_df['gameId'].isin(play_df['gameId'])) & (tracking_df['playId'].isin(play_df['playId']))]

tracking_df = pd.merge(tracking_df, players[['nflId', 'position_group']], on='nflId', how='left')

cleaned_tracking = clean.zero_coords(cleaned_tracking, play_df)

# %% [markdown]
# Now that we have have all plays from week 1 cleaned so that all plays are zeroed, we can proceed.
#
# First we select only pass plays:

# %%
play_df['playType'] = play_df['isDropback'].map({True: 'pass', False: 'run'})
plays = play_df[play_df['playType'] == 'pass']

# %% [markdown]
# Next, we want to only select plays where the defense is in man coverage

# %%
plays = plays[plays['pff_manZone'] == 'Man']

# %% [markdown]
# Only include plays in this new subset

# %%
cleaned_tracking = cleaned_tracking[(cleaned_tracking['gameId'].isin(plays['gameId'])) & (cleaned_tracking['playId'].isin(plays['playId']))]

player_plays = player_plays[(player_plays['gameId'].isin(plays['gameId'])) & (player_plays['playId'].isin(plays['playId']))]

# %% [markdown]
# Next, we need to identify the defender covering the targeted receiver for every play

# %%
# Filter target players and keep only the necessary columns
targets = player_plays[player_plays['wasTargettedReceiver'] == 1][['gameId', 'playId', 'nflId']]
targets.rename(columns={'nflId': 'target'}, inplace=True)

# Merge the target information into the plays DataFrame
plays = plays.merge(targets, on=['gameId', 'playId'], how='left')

plays.dropna(subset=['target'], inplace=True)

# %% [markdown]
# To identify the covering receiver, we can use our graph function; we can make a graph of the play and identify coverage at snap (the closest DB is the covering DB in man coverage)

# %%
covering_players = []

for index, play in plays.iterrows():
    play_graphs = clean.graph_one_play(tracking_df, play['gameId'], play['playId'], 'post')

    # Get graph at snap
    play_graph = play_graphs[0]

    # print edges in play graph
    for edge in play_graph.edges(data=True):
        print(edge)
# Out:
# (45102.0, 52411.0, {'type': 'coverage', 'distance': np.float64(23.413382925156284)})
# (47834.0, 52411.0, {'type': 'coverage', 'distance': np.float64(9.387321236646796)})
# (52411.0, 53439.0, {'type': 'coverage', 'distance': np.float64(11.82006768170132)})
# (47859.0, 53462.0, {'type': 'coverage', 'distance': np.float64(2.4229733799610775)})
# (53462.0, 54481.0, {'type': 'coverage', 'distance': np.float64(2.9011032384250015)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(1.9022355269524351)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(5.1816792644856)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(1.6617159805454096)})
# (42369.0, 52459.0, {'type': 'coverage', 'distance': np.float64(7.703719880681037)})
# (46263.0, 52459.0, {'type': 'coverage', 'distance': np.float64(9.159999999999997)})
# (52459.0, 53558.0, {'type': 'coverage', 'distance': np.float64(6.430085535978508)})
# (43344.0, 45395.0, {'type': 'coverage', 'distance': np.float64(3.955679461230389)})
# (43495.0, 45395.0, {'type': 'coverage', 'distance': np.float64(3.0464569585011376)})
# (45395.0, 53434.0, {'type': 'coverage', 'distance': np.float64(2.410331927349437)})
# (40024.0, 53596.0, {'type': 'coverage', 'distance': np.float64(2.311579546543878)})
# (53506.0, 53596.0, {'type': 'coverage', 'distance': np.float64(4.667718928984477)})
# (37079.0, 52459.0, {'type': 'coverage', 'distance': np.float64(2.005617112013158)})
# (41233.0, 52459.0, {'type': 'coverage', 'distance': np.float64(1.420035210831057)})
# (44896.0, 52459.0, {'type': 'coverage', 'distance': np.float64(6.178235994197703)})
# (43344.0, 45395.0, {'type': 'coverage', 'distance': np.float64(2.9573636908571097)})
# (43495.0, 45395.0, {'type': 'coverage', 'distance': np.float64(3.145600101729393)})
# (45395.0, 53434.0, {'type': 'coverage', 'distance': np.float64(1.6758579892102992)})
# (41230.0, 52497.0, {'type': 'coverage', 'distance': np.float64(7.2783308526062545)})
# (52497.0, 54499.0, {'type': 'coverage', 'distance': np.float64(9.552067838955102)})
# (39989.0, 53500.0, {'type': 'coverage', 'distance': np.float64(7.0011784722287995)})
# (53074.0, 53500.0, {'type': 'coverage', 'distance': np.float64(1.978206258204639)})
# (53500.0, 54628.0, {'type': 'coverage', 'distance': np.float64(2.9955300031880916)})
# (37077.0, 54486.0, {'type': 'coverage', 'distance': np.float64(2.3753947040439454)})
# (47808.0, 54486.0, {'type': 'coverage', 'distance': np.float64(1.8300273222004217)})
# (48646.0, 54486.0, {'type': 'coverage', 'distance': np.float64(7.5177456727399345)})
# (42347.0, 53437.0, {'type': 'coverage', 'distance': np.float64(6.887735476918373)})
# (52595.0, 53437.0, {'type': 'coverage', 'distance': np.float64(4.588442001376938)})
# (53437.0, 54564.0, {'type': 'coverage', 'distance': np.float64(2.0436242316042352)})
# (52500.0, 54469.0, {'type': 'coverage', 'distance': np.float64(5.310235399678627)})
# (53456.0, 54469.0, {'type': 'coverage', 'distance': np.float64(2.250022222112484)})
# (46215.0, 47849.0, {'type': 'coverage', 'distance': np.float64(1.9136614120580475)})
# (46215.0, 52457.0, {'type': 'coverage', 'distance': np.float64(3.4800143677864357)})
# (46215.0, 54517.0, {'type': 'coverage', 'distance': np.float64(7.984146792237727)})
# (41292.0, 52424.0, {'type': 'coverage', 'distance': np.float64(2.6860379744150977)})
# (52424.0, 53098.0, {'type': 'coverage', 'distance': np.float64(7.51013315461184)})
# (52424.0, 54476.0, {'type': 'coverage', 'distance': np.float64(7.129095314273744)})
# (44817.0, 54584.0, {'type': 'coverage', 'distance': np.float64(8.844297597887572)})
# (53463.0, 54584.0, {'type': 'coverage', 'distance': np.float64(1.6415846003176433)})
# (46109.0, 54618.0, {'type': 'coverage', 'distance': np.float64(2.266142096162551)})
# (52423.0, 54618.0, {'type': 'coverage', 'distance': np.float64(4.70230794397815)})
# (52454.0, 54618.0, {'type': 'coverage', 'distance': np.float64(2.80321244289476)})
# (41282.0, 53476.0, {'type': 'coverage', 'distance': np.float64(2.6754065111679846)})
# (44931.0, 53476.0, {'type': 'coverage', 'distance': np.float64(8.235417415043386)})
# (47932.0, 53476.0, {'type': 'coverage', 'distance': np.float64(8.842375246504755)})
# (47839.0, 53565.0, {'type': 'coverage', 'distance': np.float64(5.751730174477943)})
# (41292.0, 52424.0, {'type': 'coverage', 'distance': np.float64(8.729180946686808)})
# (43336.0, 52424.0, {'type': 'coverage', 'distance': np.float64(2.2848413511664214)})
# (52424.0, 54476.0, {'type': 'coverage', 'distance': np.float64(4.550966930224829)})
# (37079.0, 52459.0, {'type': 'coverage', 'distance': np.float64(6.244005124917823)})
# (41233.0, 52459.0, {'type': 'coverage', 'distance': np.float64(8.15437305989859)})
# (44896.0, 52459.0, {'type': 'coverage', 'distance': np.float64(2.5554842985234725)})
# (47859.0, 53462.0, {'type': 'coverage', 'distance': np.float64(3.1332092173999397)})
# (53462.0, 54481.0, {'type': 'coverage', 'distance': np.float64(6.03421080175362)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(9.137176806869824)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(3.790211075916486)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(7.957700672933102)})
# (43584.0, 46194.0, {'type': 'coverage', 'distance': np.float64(3.1097588330930126)})
# (44930.0, 46194.0, {'type': 'coverage', 'distance': np.float64(9.330005359055265)})
# (41290.0, 54488.0, {'type': 'coverage', 'distance': np.float64(2.5104979585731644)})
# (53678.0, 54488.0, {'type': 'coverage', 'distance': np.float64(1.8071247881648884)})
# (52411.0, 52608.0, {'type': 'coverage', 'distance': np.float64(1.630490723677995)})
# (52411.0, 53439.0, {'type': 'coverage', 'distance': np.float64(2.3690715480964295)})
# (46276.0, 46757.0, {'type': 'coverage', 'distance': np.float64(8.16682312775292)})
# (46757.0, 52581.0, {'type': 'coverage', 'distance': np.float64(1.6658931538367077)})
# (44828.0, 53463.0, {'type': 'coverage', 'distance': np.float64(5.208349066642899)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(8.642788901737681)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(11.55692433132622)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(9.173407218694697)})
# (43396.0, 46729.0, {'type': 'coverage', 'distance': np.float64(16.837256308555737)})
# (46729.0, 53518.0, {'type': 'coverage', 'distance': np.float64(2.344802763560285)})
# (42347.0, 53437.0, {'type': 'coverage', 'distance': np.float64(2.0207424378183405)})
# (52595.0, 53437.0, {'type': 'coverage', 'distance': np.float64(9.131664689419996)})
# (53437.0, 54564.0, {'type': 'coverage', 'distance': np.float64(2.6436716891474994)})
# (46698.0, 53434.0, {'type': 'coverage', 'distance': np.float64(7.764026017473157)})
# (53500.0, 54628.0, {'type': 'coverage', 'distance': np.float64(2.2339427029357726)})
# (53500.0, 54483.0, {'type': 'coverage', 'distance': np.float64(1.9816155025634987)})
# (41282.0, 53476.0, {'type': 'coverage', 'distance': np.float64(8.64743314515932)})
# (44931.0, 53476.0, {'type': 'coverage', 'distance': np.float64(8.723422493494164)})
# (47932.0, 53476.0, {'type': 'coverage', 'distance': np.float64(2.598557292037241)})
# (44823.0, 48374.0, {'type': 'coverage', 'distance': np.float64(12.289934906255604)})
# (44823.0, 54473.0, {'type': 'coverage', 'distance': np.float64(1.8322117781522946)})
# (44908.0, 54500.0, {'type': 'coverage', 'distance': np.float64(1.7990275150758526)})
# (46309.0, 54500.0, {'type': 'coverage', 'distance': np.float64(7.208196723175633)})
# (37077.0, 54486.0, {'type': 'coverage', 'distance': np.float64(2.597306296916088)})
# (47808.0, 54486.0, {'type': 'coverage', 'distance': np.float64(3.4950250356757144)})
# (47834.0, 52411.0, {'type': 'coverage', 'distance': np.float64(1.9115700353374356)})
# (52411.0, 53439.0, {'type': 'coverage', 'distance': np.float64(5.359449598606178)})
# (52411.0, 52608.0, {'type': 'coverage', 'distance': np.float64(2.3265854809140465)})
# (45052.0, 47877.0, {'type': 'coverage', 'distance': np.float64(10.483940099027654)})
# (47877.0, 55158.0, {'type': 'coverage', 'distance': np.float64(1.4069825869569232)})
# (42347.0, 53437.0, {'type': 'coverage', 'distance': np.float64(1.9132433196015555)})
# (52595.0, 53437.0, {'type': 'coverage', 'distance': np.float64(2.5533115751901607)})
# (43808.0, 54533.0, {'type': 'coverage', 'distance': np.float64(2.7142586464815763)})
# (46093.0, 54533.0, {'type': 'coverage', 'distance': np.float64(16.81951247807141)})
# (41233.0, 52459.0, {'type': 'coverage', 'distance': np.float64(8.333186665375978)})
# (42369.0, 52459.0, {'type': 'coverage', 'distance': np.float64(2.0263267258761712)})
# (46263.0, 52459.0, {'type': 'coverage', 'distance': np.float64(7.894618420164453)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(6.571407763942214)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(3.5747587331175277)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(1.5961516218705574)})
# (47877.0, 52425.0, {'type': 'coverage', 'distance': np.float64(30.818643707989487)})
# (42357.0, 54936.0, {'type': 'coverage', 'distance': np.float64(2.530474263848573)})
# (45185.0, 54936.0, {'type': 'coverage', 'distance': np.float64(2.903532331488665)})
# (48097.0, 54936.0, {'type': 'coverage', 'distance': np.float64(3.175106297433207)})
# (47842.0, 54468.0, {'type': 'coverage', 'distance': np.float64(1.683448840921514)})
# (52442.0, 54468.0, {'type': 'coverage', 'distance': np.float64(7.192009454943732)})
# (54468.0, 54518.0, {'type': 'coverage', 'distance': np.float64(5.340833268320592)})
# (47834.0, 52411.0, {'type': 'coverage', 'distance': np.float64(1.8353473785635224)})
# (52411.0, 52608.0, {'type': 'coverage', 'distance': np.float64(4.370308913566637)})
# (52411.0, 53439.0, {'type': 'coverage', 'distance': np.float64(2.7606158733152317)})
# (44874.0, 53565.0, {'type': 'coverage', 'distance': np.float64(15.664638521204374)})
# (46243.0, 53565.0, {'type': 'coverage', 'distance': np.float64(2.262741699796961)})
# (47839.0, 53565.0, {'type': 'coverage', 'distance': np.float64(6.9814898123538045)})
# (44930.0, 46194.0, {'type': 'coverage', 'distance': np.float64(7.412017269272926)})
# (46130.0, 46194.0, {'type': 'coverage', 'distance': np.float64(7.690806199612619)})
# (46194.0, 53541.0, {'type': 'coverage', 'distance': np.float64(5.614312068276932)})
# (38696.0, 53503.0, {'type': 'coverage', 'distance': np.float64(2.284841351166429)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(3.0088536022877532)})
# (46116.0, 53503.0, {'type': 'coverage', 'distance': np.float64(4.959758058615361)})
# (42347.0, 53437.0, {'type': 'coverage', 'distance': np.float64(1.9758542456365578)})
# (52595.0, 53437.0, {'type': 'coverage', 'distance': np.float64(9.364619586507503)})
# (47819.0, 54504.0, {'type': 'coverage', 'distance': np.float64(4.882007783688997)})
# (52433.0, 54504.0, {'type': 'coverage', 'distance': np.float64(4.701159431459437)})
# (53074.0, 53500.0, {'type': 'coverage', 'distance': np.float64(1.8686893802876925)})
# (42489.0, 47862.0, {'type': 'coverage', 'distance': np.float64(1.6422241016377779)})
# (47862.0, 52536.0, {'type': 'coverage', 'distance': np.float64(1.9185932346383383)})
# (43454.0, 52991.0, {'type': 'coverage', 'distance': np.float64(4.228344829835903)})
# (46277.0, 52991.0, {'type': 'coverage', 'distance': np.float64(9.317558693134169)})
# (52991.0, 53435.0, {'type': 'coverage', 'distance': np.float64(2.757480734293535)})
# (45102.0, 52411.0, {'type': 'coverage', 'distance': np.float64(5.400037036910016)})
# (47834.0, 52411.0, {'type': 'coverage', 'distance': np.float64(8.270477616196052)})
# (52411.0, 53439.0, {'type': 'coverage', 'distance': np.float64(2.809590717524525)})
# (42357.0, 54936.0, {'type': 'coverage', 'distance': np.float64(2.570700293694315)})
# (42363.0, 54936.0, {'type': 'coverage', 'distance': np.float64(3.058970415025292)})
# (48097.0, 54936.0, {'type': 'coverage', 'distance': np.float64(2.795460606054042)})
# (44817.0, 44828.0, {'type': 'coverage', 'distance': np.float64(7.383935265155025)})
# (44828.0, 53463.0, {'type': 'coverage', 'distance': np.float64(7.927294620486867)})
# (40024.0, 53596.0, {'type': 'coverage', 'distance': np.float64(2.732508005477748)})
# (44819.0, 53596.0, {'type': 'coverage', 'distance': np.float64(6.559367347541989)})
# (53506.0, 53596.0, {'type': 'coverage', 'distance': np.float64(1.8034688796871423)})
# (43808.0, 54533.0, {'type': 'coverage', 'distance': np.float64(3.5314019878796037)})
# (46093.0, 54533.0, {'type': 'coverage', 'distance': np.float64(2.043134846259536)})
# (53633.0, 54533.0, {'type': 'coverage', 'distance': np.float64(3.6818473623983907)})
# (47877.0, 52425.0, {'type': 'coverage', 'distance': np.float64(8.410998751634674)})
# (47877.0, 55158.0, {'type': 'coverage', 'distance': np.float64(2.1086725682286476)})
# (52424.0, 53098.0, {'type': 'coverage', 'distance': np.float64(2.003521899056748)})
# (52424.0, 54476.0, {'type': 'coverage', 'distance': np.float64(2.362562168494196)})
# (43344.0, 45395.0, {'type': 'coverage', 'distance': np.float64(2.4120737965493477)})
# (43495.0, 45395.0, {'type': 'coverage', 'distance': np.float64(2.310779089398208)})
# (45395.0, 53434.0, {'type': 'coverage', 'distance': np.float64(3.3618001130346813)})
# (40488.0, 53458.0, {'type': 'coverage', 'distance': np.float64(1.4270599146496934)})
# (52430.0, 53458.0, {'type': 'coverage', 'distance': np.float64(2.6126232028365672)})
# (52584.0, 53458.0, {'type': 'coverage', 'distance': np.float64(1.6150541786577952)})
# (43454.0, 52991.0, {'type': 'coverage', 'distance': np.float64(2.1749712641779997)})
# (46277.0, 52991.0, {'type': 'coverage', 'distance': np.float64(6.9165092351561235)})
# (52991.0, 53435.0, {'type': 'coverage', 'distance': np.float64(2.9623301639081387)})
# (41246.0, 45287.0, {'type': 'coverage', 'distance': np.float64(30.513528147364408)})
# (41292.0, 52424.0, {'type': 'coverage', 'distance': np.float64(3.3404490716069923)})
# (43336.0, 52424.0, {'type': 'coverage', 'distance': np.float64(8.001049931102783)})
# (48415.0, 52424.0, {'type': 'coverage', 'distance': np.float64(9.476840190696477)})
# (41233.0, 52459.0, {'type': 'coverage', 'distance': np.float64(1.3350655414622845)})
# (46263.0, 52459.0, {'type': 'coverage', 'distance': np.float64(2.2901964981197636)})
# (47842.0, 54468.0, {'type': 'coverage', 'distance': np.float64(26.72917507144581)})
# (52442.0, 54468.0, {'type': 'coverage', 'distance': np.float64(8.330918316728358)})
# (54468.0, 54518.0, {'type': 'coverage', 'distance': np.float64(8.080748727686066)})
# (43415.0, 54469.0, {'type': 'coverage', 'distance': np.float64(4.136629062413018)})
# (53456.0, 54469.0, {'type': 'coverage', 'distance': np.float64(2.287094226305511)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(2.8245353600194214)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(3.99045110231913)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(1.7042593699316995)})
# (42347.0, 53437.0, {'type': 'coverage', 'distance': np.float64(1.8109942020890095)})
# (52595.0, 53437.0, {'type': 'coverage', 'distance': np.float64(4.0796200803506135)})
# (47834.0, 52411.0, {'type': 'coverage', 'distance': np.float64(1.5498387012847403)})
# (52411.0, 53439.0, {'type': 'coverage', 'distance': np.float64(2.371181140275873)})
# (44817.0, 44828.0, {'type': 'coverage', 'distance': np.float64(1.6637307474468332)})
# (44828.0, 53463.0, {'type': 'coverage', 'distance': np.float64(1.400714103591445)})
# (44852.0, 53462.0, {'type': 'coverage', 'distance': np.float64(2.6986292816909914)})
# (47859.0, 53462.0, {'type': 'coverage', 'distance': np.float64(3.7582043584669464)})
# (53462.0, 54481.0, {'type': 'coverage', 'distance': np.float64(2.164532282041547)})
# (44819.0, 53596.0, {'type': 'coverage', 'distance': np.float64(1.5002999700059967)})
# (53506.0, 53596.0, {'type': 'coverage', 'distance': np.float64(9.036332220541693)})
# (40026.0, 53438.0, {'type': 'coverage', 'distance': np.float64(7.883869608257111)})
# (42412.0, 53438.0, {'type': 'coverage', 'distance': np.float64(3.896216113102557)})
# (47847.0, 53438.0, {'type': 'coverage', 'distance': np.float64(2.100023809388845)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(1.7713271860387536)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(3.7545305964927316)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(2.0319940944796087)})
# (43454.0, 52991.0, {'type': 'coverage', 'distance': np.float64(5.055234910466573)})
# (46277.0, 52991.0, {'type': 'coverage', 'distance': np.float64(9.682855983644496)})
# (52991.0, 53435.0, {'type': 'coverage', 'distance': np.float64(2.2968892006363792)})
# (43336.0, 52424.0, {'type': 'coverage', 'distance': np.float64(2.3703375287076778)})
# (52424.0, 54476.0, {'type': 'coverage', 'distance': np.float64(2.182773465112677)})
# (47929.0, 52608.0, {'type': 'coverage', 'distance': np.float64(4.30055810331636)})
# (47929.0, 53439.0, {'type': 'coverage', 'distance': np.float64(1.900657780874827)})
# (46243.0, 53565.0, {'type': 'coverage', 'distance': np.float64(7.584438014777354)})
# (47839.0, 53565.0, {'type': 'coverage', 'distance': np.float64(11.96636954134377)})
# (37077.0, 54708.0, {'type': 'coverage', 'distance': np.float64(7.572502888741598)})
# (47808.0, 54708.0, {'type': 'coverage', 'distance': np.float64(6.479729932643801)})
# (48646.0, 54708.0, {'type': 'coverage', 'distance': np.float64(8.116711156620026)})
# (44828.0, 53463.0, {'type': 'coverage', 'distance': np.float64(8.62294613226824)})
# (44828.0, 46279.0, {'type': 'coverage', 'distance': np.float64(5.998341437430853)})
# (43495.0, 45395.0, {'type': 'coverage', 'distance': np.float64(3.9621458832304386)})
# (44990.0, 45395.0, {'type': 'coverage', 'distance': np.float64(6.344927107540325)})
# (45395.0, 53434.0, {'type': 'coverage', 'distance': np.float64(2.241539649437426)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(3.220015527912869)})
# (44872.0, 48988.0, {'type': 'coverage', 'distance': np.float64(2.697869529832753)})
# (44872.0, 47876.0, {'type': 'coverage', 'distance': np.float64(1.791368192192771)})
# (47834.0, 52411.0, {'type': 'coverage', 'distance': np.float64(9.001422109866862)})
# (52411.0, 52608.0, {'type': 'coverage', 'distance': np.float64(8.219787101865833)})
# (52411.0, 53439.0, {'type': 'coverage', 'distance': np.float64(11.466481587653643)})
# (44930.0, 46194.0, {'type': 'coverage', 'distance': np.float64(1.9188017094009524)})
# (46194.0, 53541.0, {'type': 'coverage', 'distance': np.float64(5.8597696200447995)})
# (42347.0, 53437.0, {'type': 'coverage', 'distance': np.float64(2.4001041644062178)})
# (52595.0, 53437.0, {'type': 'coverage', 'distance': np.float64(3.2046528673165224)})
# (52595.0, 53437.0, {'type': 'coverage', 'distance': np.float64(6.358569021407253)})
# (53437.0, 53520.0, {'type': 'coverage', 'distance': np.float64(1.9601020381602594)})
# (46276.0, 46757.0, {'type': 'coverage', 'distance': np.float64(3.799065674610017)})
# (46522.0, 46757.0, {'type': 'coverage', 'distance': np.float64(13.268025474802194)})
# (44908.0, 54500.0, {'type': 'coverage', 'distance': np.float64(1.3480726983364186)})
# (46309.0, 54500.0, {'type': 'coverage', 'distance': np.float64(2.1718655575334327)})
# (48489.0, 54500.0, {'type': 'coverage', 'distance': np.float64(4.680865304620501)})
# (41246.0, 46729.0, {'type': 'coverage', 'distance': np.float64(6.50120758013463)})
# (43396.0, 46729.0, {'type': 'coverage', 'distance': np.float64(3.798631332466994)})
# (46729.0, 53518.0, {'type': 'coverage', 'distance': np.float64(2.3872368964977078)})
# (44874.0, 53565.0, {'type': 'coverage', 'distance': np.float64(4.635353276720121)})
# (46243.0, 53565.0, {'type': 'coverage', 'distance': np.float64(1.967028215354317)})
# (44930.0, 46194.0, {'type': 'coverage', 'distance': np.float64(5.027772866787042)})
# (46130.0, 46194.0, {'type': 'coverage', 'distance': np.float64(8.484933706281977)})
# (42357.0, 54936.0, {'type': 'coverage', 'distance': np.float64(8.304366321399847)})
# (42363.0, 54936.0, {'type': 'coverage', 'distance': np.float64(2.8935272592460515)})
# (48097.0, 54936.0, {'type': 'coverage', 'distance': np.float64(3.5320390711315763)})
# (46279.0, 54606.0, {'type': 'coverage', 'distance': np.float64(2.6415336454416027)})
# (53463.0, 54606.0, {'type': 'coverage', 'distance': np.float64(2.173683509621389)})
# (54475.0, 54606.0, {'type': 'coverage', 'distance': np.float64(2.6204770558049204)})
# (42794.0, 53596.0, {'type': 'coverage', 'distance': np.float64(2.7124896313165907)})
# (53506.0, 53596.0, {'type': 'coverage', 'distance': np.float64(1.5616017418023047)})
# (47819.0, 54504.0, {'type': 'coverage', 'distance': np.float64(2.0267461607216606)})
# (52433.0, 54504.0, {'type': 'coverage', 'distance': np.float64(0.9924716620639623)})
# (44874.0, 53565.0, {'type': 'coverage', 'distance': np.float64(1.9464840096954321)})
# (46243.0, 53565.0, {'type': 'coverage', 'distance': np.float64(8.764593544483391)})
# (44852.0, 53462.0, {'type': 'coverage', 'distance': np.float64(5.051227573570607)})
# (47859.0, 53462.0, {'type': 'coverage', 'distance': np.float64(3.696877060438984)})
# (53462.0, 54481.0, {'type': 'coverage', 'distance': np.float64(2.9728437564056396)})
# (41282.0, 53476.0, {'type': 'coverage', 'distance': np.float64(4.504808541991561)})
# (44931.0, 53476.0, {'type': 'coverage', 'distance': np.float64(3.0078730026382496)})
# (46243.0, 53565.0, {'type': 'coverage', 'distance': np.float64(2.244147945212166)})
# (47839.0, 53565.0, {'type': 'coverage', 'distance': np.float64(3.9348951701411354)})
# (47859.0, 53462.0, {'type': 'coverage', 'distance': np.float64(4.808846015417836)})
# (53462.0, 54481.0, {'type': 'coverage', 'distance': np.float64(6.335337402222551)})
# (39989.0, 53500.0, {'type': 'coverage', 'distance': np.float64(11.411853486616451)})
# (53074.0, 53500.0, {'type': 'coverage', 'distance': np.float64(1.5546382215808252)})
# (43344.0, 45395.0, {'type': 'coverage', 'distance': np.float64(2.0565018842685183)})
# (45395.0, 53434.0, {'type': 'coverage', 'distance': np.float64(1.9513328778042949)})
# (45395.0, 48530.0, {'type': 'coverage', 'distance': np.float64(1.8445866745696748)})
# (43454.0, 54586.0, {'type': 'coverage', 'distance': np.float64(8.773836105148076)})
# (46671.0, 54586.0, {'type': 'coverage', 'distance': np.float64(2.8700000000000045)})
# (53435.0, 54586.0, {'type': 'coverage', 'distance': np.float64(2.5728000310945345)})
# (40026.0, 53438.0, {'type': 'coverage', 'distance': np.float64(2.178302091079188)})
# (42412.0, 53438.0, {'type': 'coverage', 'distance': np.float64(7.064170156501046)})
# (53565.0, 54519.0, {'type': 'coverage', 'distance': np.float64(4.218649072866817)})
# (44874.0, 53565.0, {'type': 'coverage', 'distance': np.float64(1.9204166214652432)})
# (46213.0, 53565.0, {'type': 'coverage', 'distance': np.float64(2.0875344308537764)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(8.505645184229117)})
# (46116.0, 53503.0, {'type': 'coverage', 'distance': np.float64(8.108298218491969)})
# (44874.0, 53565.0, {'type': 'coverage', 'distance': np.float64(9.188694140083236)})
# (46243.0, 53565.0, {'type': 'coverage', 'distance': np.float64(16.080360692472045)})
# (41292.0, 52424.0, {'type': 'coverage', 'distance': np.float64(2.6591163945942706)})
# (43336.0, 52424.0, {'type': 'coverage', 'distance': np.float64(3.3778395462188526)})
# (52424.0, 54476.0, {'type': 'coverage', 'distance': np.float64(7.870006353237586)})
# (43344.0, 45395.0, {'type': 'coverage', 'distance': np.float64(5.234500931320963)})
# (43495.0, 45395.0, {'type': 'coverage', 'distance': np.float64(2.3707593720156463)})
# (43329.0, 54500.0, {'type': 'coverage', 'distance': np.float64(4.9616630276551446)})
# (44908.0, 54500.0, {'type': 'coverage', 'distance': np.float64(2.0270421801235425)})
# (40488.0, 53458.0, {'type': 'coverage', 'distance': np.float64(12.905223748544616)})
# (52430.0, 53458.0, {'type': 'coverage', 'distance': np.float64(7.146726523381177)})
# (44852.0, 53462.0, {'type': 'coverage', 'distance': np.float64(7.548039480553871)})
# (47859.0, 53462.0, {'type': 'coverage', 'distance': np.float64(2.4816325271884936)})
# (46276.0, 46757.0, {'type': 'coverage', 'distance': np.float64(16.485269181909043)})
# (46757.0, 52581.0, {'type': 'coverage', 'distance': np.float64(1.5126797413861248)})
# (44852.0, 53462.0, {'type': 'coverage', 'distance': np.float64(3.9549715548913964)})
# (53462.0, 54481.0, {'type': 'coverage', 'distance': np.float64(2.201454064930725)})
# (47839.0, 53565.0, {'type': 'coverage', 'distance': np.float64(12.719889936630738)})
# (53565.0, 54519.0, {'type': 'coverage', 'distance': np.float64(3.295603131446499)})
# (42357.0, 48476.0, {'type': 'coverage', 'distance': np.float64(2.371708245126282)})
# (42363.0, 48476.0, {'type': 'coverage', 'distance': np.float64(4.187660444687464)})
# (48097.0, 48476.0, {'type': 'coverage', 'distance': np.float64(3.6652557891639694)})
# (52442.0, 54468.0, {'type': 'coverage', 'distance': np.float64(5.467888074933506)})
# (53658.0, 54468.0, {'type': 'coverage', 'distance': np.float64(6.606125944909015)})
# (44828.0, 54475.0, {'type': 'coverage', 'distance': np.float64(9.425481420065507)})
# (44828.0, 48657.0, {'type': 'coverage', 'distance': np.float64(1.5219066988485248)})
# (42794.0, 53596.0, {'type': 'coverage', 'distance': np.float64(1.8189282558693798)})
# (44819.0, 53596.0, {'type': 'coverage', 'distance': np.float64(2.0570367036103145)})
# (53506.0, 53596.0, {'type': 'coverage', 'distance': np.float64(2.974054471592604)})
# (44874.0, 53565.0, {'type': 'coverage', 'distance': np.float64(1.911256131448636)})
# (46243.0, 53565.0, {'type': 'coverage', 'distance': np.float64(3.170015772831424)})
# (47839.0, 53565.0, {'type': 'coverage', 'distance': np.float64(2.1128653530218147)})
# (45102.0, 52411.0, {'type': 'coverage', 'distance': np.float64(6.208252572181644)})
# (52411.0, 53439.0, {'type': 'coverage', 'distance': np.float64(2.1574522010927746)})
# (44930.0, 46194.0, {'type': 'coverage', 'distance': np.float64(2.181604913819181)})
# (46130.0, 46194.0, {'type': 'coverage', 'distance': np.float64(1.5768956845650857)})
# (42357.0, 48476.0, {'type': 'coverage', 'distance': np.float64(2.242431715794256)})
# (48097.0, 48476.0, {'type': 'coverage', 'distance': np.float64(2.4253865671269854)})
# (44874.0, 53565.0, {'type': 'coverage', 'distance': np.float64(2.0101989951246106)})
# (46243.0, 53565.0, {'type': 'coverage', 'distance': np.float64(5.519510847892239)})
# (47839.0, 53565.0, {'type': 'coverage', 'distance': np.float64(2.76739950133695)})
# (47808.0, 54708.0, {'type': 'coverage', 'distance': np.float64(1.5523208431249047)})
# (47845.0, 54708.0, {'type': 'coverage', 'distance': np.float64(2.260000000000005)})
# (48646.0, 54708.0, {'type': 'coverage', 'distance': np.float64(6.287837466092769)})
# (44930.0, 46194.0, {'type': 'coverage', 'distance': np.float64(2.2522211259110416)})
# (46130.0, 46194.0, {'type': 'coverage', 'distance': np.float64(8.627774915932848)})
# (46194.0, 53541.0, {'type': 'coverage', 'distance': np.float64(4.573193632462993)})
# (47842.0, 54468.0, {'type': 'coverage', 'distance': np.float64(9.381284560229476)})
# (52442.0, 54468.0, {'type': 'coverage', 'distance': np.float64(8.801278316244753)})
# (54468.0, 54518.0, {'type': 'coverage', 'distance': np.float64(2.563825267057015)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(3.170252355885886)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(4.870657039866392)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(1.9116746585127886)})
# (45052.0, 47877.0, {'type': 'coverage', 'distance': np.float64(4.520409273506106)})
# (47877.0, 52425.0, {'type': 'coverage', 'distance': np.float64(1.8844893207444846)})
# (40488.0, 53458.0, {'type': 'coverage', 'distance': np.float64(8.075951956271169)})
# (52430.0, 53458.0, {'type': 'coverage', 'distance': np.float64(2.3005434140654732)})
# (47834.0, 52411.0, {'type': 'coverage', 'distance': np.float64(1.8895766721675942)})
# (52411.0, 52608.0, {'type': 'coverage', 'distance': np.float64(4.230898249781002)})
# (52411.0, 53439.0, {'type': 'coverage', 'distance': np.float64(2.25055548698538)})
# (38696.0, 53503.0, {'type': 'coverage', 'distance': np.float64(7.471773551172442)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(17.897508206451533)})
# (46116.0, 53503.0, {'type': 'coverage', 'distance': np.float64(4.09353148271757)})
# (44931.0, 53476.0, {'type': 'coverage', 'distance': np.float64(8.999361088432893)})
# (47932.0, 53476.0, {'type': 'coverage', 'distance': np.float64(7.101922274990058)})
# (48601.0, 53476.0, {'type': 'coverage', 'distance': np.float64(2.267619897601889)})
# (38696.0, 53503.0, {'type': 'coverage', 'distance': np.float64(3.3201957773601265)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(3.187098994383445)})
# (46116.0, 53503.0, {'type': 'coverage', 'distance': np.float64(3.6001111093964777)})
# (42347.0, 53437.0, {'type': 'coverage', 'distance': np.float64(2.842129483327602)})
# (52595.0, 53437.0, {'type': 'coverage', 'distance': np.float64(4.425031073337231)})
# (40026.0, 53438.0, {'type': 'coverage', 'distance': np.float64(9.000005555553841)})
# (42412.0, 53438.0, {'type': 'coverage', 'distance': np.float64(8.480053065871703)})
# (47847.0, 53438.0, {'type': 'coverage', 'distance': np.float64(9.492944748601454)})
# (41292.0, 52424.0, {'type': 'coverage', 'distance': np.float64(3.261717339071557)})
# (43336.0, 52424.0, {'type': 'coverage', 'distance': np.float64(2.5951493213300902)})
# (52424.0, 54476.0, {'type': 'coverage', 'distance': np.float64(9.48996311900104)})
# (44828.0, 54475.0, {'type': 'coverage', 'distance': np.float64(9.761808234133674)})
# (44828.0, 48657.0, {'type': 'coverage', 'distance': np.float64(1.5825612152457296)})
# (44930.0, 46194.0, {'type': 'coverage', 'distance': np.float64(6.125104080748347)})
# (46130.0, 46194.0, {'type': 'coverage', 'distance': np.float64(4.891175727777522)})
# (46194.0, 53541.0, {'type': 'coverage', 'distance': np.float64(2.1866183937761132)})
# (37079.0, 52459.0, {'type': 'coverage', 'distance': np.float64(1.7147011401407513)})
# (41233.0, 52459.0, {'type': 'coverage', 'distance': np.float64(2.4473046398027454)})
# (46263.0, 52459.0, {'type': 'coverage', 'distance': np.float64(3.0326556019436217)})
# (43454.0, 54586.0, {'type': 'coverage', 'distance': np.float64(2.696738771182711)})
# (46277.0, 54586.0, {'type': 'coverage', 'distance': np.float64(7.775815069817446)})
# (53435.0, 54586.0, {'type': 'coverage', 'distance': np.float64(2.9110994486619624)})
# (52500.0, 54469.0, {'type': 'coverage', 'distance': np.float64(13.48196202338517)})
# (53456.0, 54469.0, {'type': 'coverage', 'distance': np.float64(2.3345235059857505)})
# (43495.0, 46698.0, {'type': 'coverage', 'distance': np.float64(3.393464306575204)})
# (46698.0, 53434.0, {'type': 'coverage', 'distance': np.float64(2.8792012781325154)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(3.6577588766893867)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(4.13000000000001)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(3.0891584614584056)})
# (46215.0, 54517.0, {'type': 'coverage', 'distance': np.float64(3.765952734700742)})
# (46215.0, 52457.0, {'type': 'coverage', 'distance': np.float64(6.774075582690228)})
# (46215.0, 47849.0, {'type': 'coverage', 'distance': np.float64(8.254847060969695)})
# (41233.0, 52459.0, {'type': 'coverage', 'distance': np.float64(1.7904468715937851)})
# (42369.0, 52459.0, {'type': 'coverage', 'distance': np.float64(2.691635190734428)})
# (46263.0, 52459.0, {'type': 'coverage', 'distance': np.float64(6.44323676423582)})
# (45052.0, 47877.0, {'type': 'coverage', 'distance': np.float64(3.897601826764762)})
# (47877.0, 53608.0, {'type': 'coverage', 'distance': np.float64(2.6879360111431243)})
# (41292.0, 52424.0, {'type': 'coverage', 'distance': np.float64(6.802095265431082)})
# (43336.0, 52424.0, {'type': 'coverage', 'distance': np.float64(2.653770901943121)})
# (48415.0, 52424.0, {'type': 'coverage', 'distance': np.float64(2.5228555249954323)})
# (40488.0, 53458.0, {'type': 'coverage', 'distance': np.float64(2.8208154849262908)})
# (52430.0, 53458.0, {'type': 'coverage', 'distance': np.float64(2.4780839372386065)})
# (52584.0, 53458.0, {'type': 'coverage', 'distance': np.float64(7.46860093993514)})
# (43808.0, 54533.0, {'type': 'coverage', 'distance': np.float64(3.510270644836368)})
# (46093.0, 54533.0, {'type': 'coverage', 'distance': np.float64(3.912569488200819)})
# (53633.0, 54533.0, {'type': 'coverage', 'distance': np.float64(13.049398453568658)})
# (43396.0, 46729.0, {'type': 'coverage', 'distance': np.float64(9.574486931423534)})
# (46729.0, 53518.0, {'type': 'coverage', 'distance': np.float64(7.8139618632291805)})
# (42794.0, 53596.0, {'type': 'coverage', 'distance': np.float64(2.876404005003474)})
# (44819.0, 53596.0, {'type': 'coverage', 'distance': np.float64(4.588093285886862)})
# (53506.0, 53596.0, {'type': 'coverage', 'distance': np.float64(2.846067462306539)})
# (46243.0, 53565.0, {'type': 'coverage', 'distance': np.float64(19.81157489953789)})
# (43344.0, 46698.0, {'type': 'coverage', 'distance': np.float64(7.445978780523077)})
# (46698.0, 53434.0, {'type': 'coverage', 'distance': np.float64(7.779177334397251)})
# (38696.0, 53503.0, {'type': 'coverage', 'distance': np.float64(5.153212590219823)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(8.681255669544585)})
# (42347.0, 53437.0, {'type': 'coverage', 'distance': np.float64(3.1338315206787866)})
# (52595.0, 53437.0, {'type': 'coverage', 'distance': np.float64(3.3174689146998775)})
# (53437.0, 53520.0, {'type': 'coverage', 'distance': np.float64(2.3907530194480575)})
# (43344.0, 45395.0, {'type': 'coverage', 'distance': np.float64(3.470014409191984)})
# (43495.0, 45395.0, {'type': 'coverage', 'distance': np.float64(6.15997564930252)})
# (45395.0, 53434.0, {'type': 'coverage', 'distance': np.float64(6.949201392965959)})
# (46093.0, 54533.0, {'type': 'coverage', 'distance': np.float64(4.732293312972055)})
# (47834.0, 52411.0, {'type': 'coverage', 'distance': np.float64(3.3832085362862307)})
# (52411.0, 53439.0, {'type': 'coverage', 'distance': np.float64(4.765427577877984)})
# (52411.0, 52608.0, {'type': 'coverage', 'distance': np.float64(2.0124611797498146)})
# (39989.0, 53500.0, {'type': 'coverage', 'distance': np.float64(2.293403584195324)})
# (53500.0, 54628.0, {'type': 'coverage', 'distance': np.float64(2.678992347880072)})
# (53500.0, 54483.0, {'type': 'coverage', 'distance': np.float64(1.8002499826413112)})
# (42357.0, 48476.0, {'type': 'coverage', 'distance': np.float64(2.4900803199896933)})
# (48097.0, 48476.0, {'type': 'coverage', 'distance': np.float64(3.309637442379444)})
# (42412.0, 53438.0, {'type': 'coverage', 'distance': np.float64(15.625447193600573)})
# (47847.0, 53438.0, {'type': 'coverage', 'distance': np.float64(9.101604254196076)})
# (45052.0, 47877.0, {'type': 'coverage', 'distance': np.float64(2.656350880437292)})
# (47877.0, 53608.0, {'type': 'coverage', 'distance': np.float64(10.151305334783304)})
# (43495.0, 45395.0, {'type': 'coverage', 'distance': np.float64(2.4836465126905733)})
# (44990.0, 45395.0, {'type': 'coverage', 'distance': np.float64(6.081529412902651)})
# (45395.0, 53434.0, {'type': 'coverage', 'distance': np.float64(5.521530584901251)})
# (40024.0, 53596.0, {'type': 'coverage', 'distance': np.float64(2.230807028857484)})
# (44819.0, 53596.0, {'type': 'coverage', 'distance': np.float64(1.2403628501370023)})
# (37079.0, 52459.0, {'type': 'coverage', 'distance': np.float64(17.485931487913366)})
# (41233.0, 52459.0, {'type': 'coverage', 'distance': np.float64(1.5984054554461522)})
# (46277.0, 52991.0, {'type': 'coverage', 'distance': np.float64(8.272925721895499)})
# (46671.0, 52991.0, {'type': 'coverage', 'distance': np.float64(7.071810235010559)})
# (41292.0, 52424.0, {'type': 'coverage', 'distance': np.float64(6.776916703044233)})
# (43336.0, 52424.0, {'type': 'coverage', 'distance': np.float64(5.226337149476669)})
# (52424.0, 54476.0, {'type': 'coverage', 'distance': np.float64(7.793587107359487)})
# (43344.0, 45395.0, {'type': 'coverage', 'distance': np.float64(4.86646689087679)})
# (45395.0, 53434.0, {'type': 'coverage', 'distance': np.float64(10.369339419654464)})
# (45395.0, 52441.0, {'type': 'coverage', 'distance': np.float64(9.00943949421939)})
# (44930.0, 46194.0, {'type': 'coverage', 'distance': np.float64(9.90305508416469)})
# (46130.0, 46194.0, {'type': 'coverage', 'distance': np.float64(7.355848013655532)})
# (46194.0, 53541.0, {'type': 'coverage', 'distance': np.float64(3.5501267583003258)})
# (38696.0, 53503.0, {'type': 'coverage', 'distance': np.float64(3.327596730374637)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(7.457217979917177)})
# (43415.0, 54469.0, {'type': 'coverage', 'distance': np.float64(4.825608769885926)})
# (53456.0, 54469.0, {'type': 'coverage', 'distance': np.float64(2.041568024827967)})
# (38696.0, 53503.0, {'type': 'coverage', 'distance': np.float64(4.544722213733198)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(5.188689622631134)})
# (46116.0, 53503.0, {'type': 'coverage', 'distance': np.float64(3.9606312628165754)})
# (45102.0, 52411.0, {'type': 'coverage', 'distance': np.float64(9.410812929816425)})
# (47834.0, 52411.0, {'type': 'coverage', 'distance': np.float64(1.685763921787385)})
# (38696.0, 53503.0, {'type': 'coverage', 'distance': np.float64(2.6443902888945714)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(1.9933138237618184)})
# (41246.0, 46729.0, {'type': 'coverage', 'distance': np.float64(6.955638000931334)})
# (43396.0, 46729.0, {'type': 'coverage', 'distance': np.float64(8.057449968817684)})
# (41246.0, 46729.0, {'type': 'coverage', 'distance': np.float64(8.762699355792133)})
# (43396.0, 46729.0, {'type': 'coverage', 'distance': np.float64(15.750479357784638)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(15.66625992379802)})
# (46116.0, 53503.0, {'type': 'coverage', 'distance': np.float64(2.1044714300745504)})
# (44823.0, 52489.0, {'type': 'coverage', 'distance': np.float64(6.2543185080390655)})
# (44823.0, 54473.0, {'type': 'coverage', 'distance': np.float64(2.045336158190141)})
# (42794.0, 53596.0, {'type': 'coverage', 'distance': np.float64(2.0211135544545735)})
# (44819.0, 53596.0, {'type': 'coverage', 'distance': np.float64(3.2819658742893676)})
# (53506.0, 53596.0, {'type': 'coverage', 'distance': np.float64(2.4707286374670945)})
# (52500.0, 54469.0, {'type': 'coverage', 'distance': np.float64(2.5877403270034636)})
# (53456.0, 54469.0, {'type': 'coverage', 'distance': np.float64(5.089528465388519)})
# (44817.0, 44828.0, {'type': 'coverage', 'distance': np.float64(2.6736678926149335)})
# (44828.0, 46279.0, {'type': 'coverage', 'distance': np.float64(1.7510282693320516)})
# (44930.0, 46194.0, {'type': 'coverage', 'distance': np.float64(3.3129594021056183)})
# (46130.0, 46194.0, {'type': 'coverage', 'distance': np.float64(2.4935917869611335)})
# (43344.0, 46698.0, {'type': 'coverage', 'distance': np.float64(7.314273716508019)})
# (43495.0, 46698.0, {'type': 'coverage', 'distance': np.float64(6.679775445327491)})
# (46698.0, 53434.0, {'type': 'coverage', 'distance': np.float64(6.595005686123408)})
# (53506.0, 53596.0, {'type': 'coverage', 'distance': np.float64(2.0612860063562275)})
# (44817.0, 44828.0, {'type': 'coverage', 'distance': np.float64(2.810427013818362)})
# (43454.0, 52991.0, {'type': 'coverage', 'distance': np.float64(1.6876018487783113)})
# (52991.0, 53435.0, {'type': 'coverage', 'distance': np.float64(2.5538402455909415)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(5.4512475636316475)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(4.9751080390278934)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(5.860511923031978)})
# (44823.0, 46992.0, {'type': 'coverage', 'distance': np.float64(2.9064411227478817)})
# (44823.0, 48374.0, {'type': 'coverage', 'distance': np.float64(9.16299623485681)})
# (47877.0, 55158.0, {'type': 'coverage', 'distance': np.float64(8.596045602484901)})
# (47877.0, 52425.0, {'type': 'coverage', 'distance': np.float64(5.289281614737484)})
# (46243.0, 53565.0, {'type': 'coverage', 'distance': np.float64(3.816084380618435)})
# (47839.0, 53565.0, {'type': 'coverage', 'distance': np.float64(7.294443090462755)})
# (44828.0, 53463.0, {'type': 'coverage', 'distance': np.float64(7.054431231502647)})
# (44828.0, 54475.0, {'type': 'coverage', 'distance': np.float64(4.645621594576976)})
# (38696.0, 53503.0, {'type': 'coverage', 'distance': np.float64(3.8189527360259348)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(1.7593180496999345)})
# (46116.0, 53503.0, {'type': 'coverage', 'distance': np.float64(2.877672670753215)})
# (39989.0, 53500.0, {'type': 'coverage', 'distance': np.float64(2.2227235545609396)})
# (53074.0, 53500.0, {'type': 'coverage', 'distance': np.float64(1.8921416437465708)})
# (53500.0, 54628.0, {'type': 'coverage', 'distance': np.float64(2.9506101064017267)})
# (42794.0, 53596.0, {'type': 'coverage', 'distance': np.float64(4.841497702157873)})
# (53506.0, 53596.0, {'type': 'coverage', 'distance': np.float64(2.350170206602069)})
# (44874.0, 53565.0, {'type': 'coverage', 'distance': np.float64(2.929044212708304)})
# (46213.0, 53565.0, {'type': 'coverage', 'distance': np.float64(15.427585682795605)})
# (38696.0, 53503.0, {'type': 'coverage', 'distance': np.float64(8.187111822859144)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(2.270352395554498)})
# (46116.0, 53503.0, {'type': 'coverage', 'distance': np.float64(16.13563757649508)})
# (44985.0, 47862.0, {'type': 'coverage', 'distance': np.float64(11.827024139655759)})
# (47862.0, 52536.0, {'type': 'coverage', 'distance': np.float64(7.722544917318392)})
# (44852.0, 53462.0, {'type': 'coverage', 'distance': np.float64(3.58871843420461)})
# (46362.0, 53462.0, {'type': 'coverage', 'distance': np.float64(2.6500000000000004)})
# (53462.0, 54481.0, {'type': 'coverage', 'distance': np.float64(8.647918824780911)})
# (43495.0, 45395.0, {'type': 'coverage', 'distance': np.float64(8.563649922784096)})
# (44990.0, 45395.0, {'type': 'coverage', 'distance': np.float64(4.543236731670496)})
# (45395.0, 53434.0, {'type': 'coverage', 'distance': np.float64(6.7050428783118186)})
# (39989.0, 53500.0, {'type': 'coverage', 'distance': np.float64(9.411041387646742)})
# (53500.0, 54483.0, {'type': 'coverage', 'distance': np.float64(5.864639801385937)})
# (53500.0, 54628.0, {'type': 'coverage', 'distance': np.float64(9.410260357715929)})
# (43329.0, 54500.0, {'type': 'coverage', 'distance': np.float64(2.2996521476084166)})
# (44908.0, 54500.0, {'type': 'coverage', 'distance': np.float64(2.2601991062736024)})
# (46309.0, 54500.0, {'type': 'coverage', 'distance': np.float64(8.364125776194427)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(9.432221371447982)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(11.036616329292237)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(8.643477309509166)})
# (37079.0, 52459.0, {'type': 'coverage', 'distance': np.float64(9.110664081174324)})
# (42369.0, 52459.0, {'type': 'coverage', 'distance': np.float64(1.9678668654154414)})
# (46263.0, 52459.0, {'type': 'coverage', 'distance': np.float64(7.074079445411954)})
# (44823.0, 52489.0, {'type': 'coverage', 'distance': np.float64(7.608054941967765)})
# (44823.0, 54473.0, {'type': 'coverage', 'distance': np.float64(1.935691091057668)})
# (41292.0, 52424.0, {'type': 'coverage', 'distance': np.float64(6.767104255144876)})
# (43336.0, 52424.0, {'type': 'coverage', 'distance': np.float64(1.9927117202445506)})
# (52424.0, 54476.0, {'type': 'coverage', 'distance': np.float64(5.611702059090453)})
# (44930.0, 46194.0, {'type': 'coverage', 'distance': np.float64(19.952944644838766)})
# (46130.0, 46194.0, {'type': 'coverage', 'distance': np.float64(7.089033784656411)})
# (46194.0, 53541.0, {'type': 'coverage', 'distance': np.float64(2.650000000000002)})
# (47834.0, 52411.0, {'type': 'coverage', 'distance': np.float64(3.182766092567921)})
# (52411.0, 52608.0, {'type': 'coverage', 'distance': np.float64(3.8808246546320495)})
# (52411.0, 53439.0, {'type': 'coverage', 'distance': np.float64(6.953387663578083)})
# (43329.0, 54500.0, {'type': 'coverage', 'distance': np.float64(8.187429389008487)})
# (44908.0, 54500.0, {'type': 'coverage', 'distance': np.float64(1.5206906325745548)})
# (39989.0, 53500.0, {'type': 'coverage', 'distance': np.float64(2.249644416346729)})
# (53074.0, 53500.0, {'type': 'coverage', 'distance': np.float64(3.3012118986820624)})
# (44823.0, 52489.0, {'type': 'coverage', 'distance': np.float64(2.8327018904219408)})
# (44823.0, 54473.0, {'type': 'coverage', 'distance': np.float64(2.040612653101996)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(4.821306876771072)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(2.012063617284503)})
# (39989.0, 53500.0, {'type': 'coverage', 'distance': np.float64(8.140227269554584)})
# (53500.0, 54628.0, {'type': 'coverage', 'distance': np.float64(7.582216034906933)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(11.81085094309466)})
# (46116.0, 53503.0, {'type': 'coverage', 'distance': np.float64(3.952379030406869)})
# (37079.0, 52459.0, {'type': 'coverage', 'distance': np.float64(3.1863615614051066)})
# (41233.0, 52459.0, {'type': 'coverage', 'distance': np.float64(3.1845407832213426)})
# (41290.0, 54488.0, {'type': 'coverage', 'distance': np.float64(2.4847736315407016)})
# (44881.0, 54488.0, {'type': 'coverage', 'distance': np.float64(3.005395148728367)})
# (53678.0, 54488.0, {'type': 'coverage', 'distance': np.float64(4.172589124272841)})
# (43454.0, 54586.0, {'type': 'coverage', 'distance': np.float64(7.064233857963649)})
# (46277.0, 54586.0, {'type': 'coverage', 'distance': np.float64(9.602551744197996)})
# (46671.0, 54586.0, {'type': 'coverage', 'distance': np.float64(2.081730049742284)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(10.583028867011562)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(11.179736132843207)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(8.960809115252934)})
# (37077.0, 54486.0, {'type': 'coverage', 'distance': np.float64(3.1491586177898307)})
# (47808.0, 54486.0, {'type': 'coverage', 'distance': np.float64(1.7933767033169574)})
# (48646.0, 54486.0, {'type': 'coverage', 'distance': np.float64(2.4724481794367357)})
# (41282.0, 53476.0, {'type': 'coverage', 'distance': np.float64(8.044532304615354)})
# (44931.0, 53476.0, {'type': 'coverage', 'distance': np.float64(7.190111264785822)})
# (47932.0, 53476.0, {'type': 'coverage', 'distance': np.float64(3.119246703933499)})
# (44817.0, 44828.0, {'type': 'coverage', 'distance': np.float64(1.3138112497615517)})
# (44828.0, 53463.0, {'type': 'coverage', 'distance': np.float64(1.4956603892595421)})
# (47859.0, 53462.0, {'type': 'coverage', 'distance': np.float64(2.0227703774773858)})
# (53462.0, 54481.0, {'type': 'coverage', 'distance': np.float64(5.043114117289033)})
# (38696.0, 53503.0, {'type': 'coverage', 'distance': np.float64(2.365797962633325)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(4.343972836010838)})
# (46116.0, 53503.0, {'type': 'coverage', 'distance': np.float64(5.341956570396289)})
# (43454.0, 43700.0, {'type': 'coverage', 'distance': np.float64(12.582722280969255)})
# (43700.0, 53435.0, {'type': 'coverage', 'distance': np.float64(8.652311829794401)})
# (43344.0, 45395.0, {'type': 'coverage', 'distance': np.float64(5.333488539408318)})
# (43495.0, 45395.0, {'type': 'coverage', 'distance': np.float64(2.8425340807103825)})
# (45395.0, 53434.0, {'type': 'coverage', 'distance': np.float64(2.0302216627747827)})
# (44872.0, 54517.0, {'type': 'coverage', 'distance': np.float64(9.153125149368384)})
# (44872.0, 52457.0, {'type': 'coverage', 'distance': np.float64(11.257655173258772)})
# (44872.0, 47849.0, {'type': 'coverage', 'distance': np.float64(9.005087450991246)})
# (42347.0, 53437.0, {'type': 'coverage', 'distance': np.float64(1.7681911661356127)})
# (41292.0, 52424.0, {'type': 'coverage', 'distance': np.float64(3.3673283178211153)})
# (43336.0, 52424.0, {'type': 'coverage', 'distance': np.float64(1.9304144632694782)})
# (52424.0, 54476.0, {'type': 'coverage', 'distance': np.float64(3.9855739862659694)})
# (41292.0, 52424.0, {'type': 'coverage', 'distance': np.float64(2.6222509414623194)})
# (43336.0, 52424.0, {'type': 'coverage', 'distance': np.float64(3.818861086763961)})
# (52424.0, 54476.0, {'type': 'coverage', 'distance': np.float64(2.4734793308212657)})
# (37077.0, 54486.0, {'type': 'coverage', 'distance': np.float64(2.4812899870833354)})
# (47808.0, 54486.0, {'type': 'coverage', 'distance': np.float64(6.924637174610663)})
# (48646.0, 54486.0, {'type': 'coverage', 'distance': np.float64(2.8961353559528233)})
# (38696.0, 53503.0, {'type': 'coverage', 'distance': np.float64(5.61975978134297)})
# (44849.0, 53503.0, {'type': 'coverage', 'distance': np.float64(3.608670115153235)})
# (46116.0, 53503.0, {'type': 'coverage', 'distance': np.float64(6.502999308011653)})
# (37077.0, 54486.0, {'type': 'coverage', 'distance': np.float64(7.406119091670086)})
# (48646.0, 54486.0, {'type': 'coverage', 'distance': np.float64(9.742484282768944)})
# (44874.0, 53565.0, {'type': 'coverage', 'distance': np.float64(1.9996999774966213)})
# (46243.0, 53565.0, {'type': 'coverage', 'distance': np.float64(2.915561695454236)})
# (47839.0, 53565.0, {'type': 'coverage', 'distance': np.float64(1.9137659209004674)})
# (42818.0, 47862.0, {'type': 'coverage', 'distance': np.float64(9.681554627228008)})
# (44985.0, 47862.0, {'type': 'coverage', 'distance': np.float64(7.869949173914652)})
# (47862.0, 52536.0, {'type': 'coverage', 'distance': np.float64(2.7226457720386605)})
# (46243.0, 53565.0, {'type': 'coverage', 'distance': np.float64(9.42096067288257)})
# (47839.0, 53565.0, {'type': 'coverage', 'distance': np.float64(8.195395048440313)})

# %%
plays.head()
# Out:
#        gameId  playId                                    playDescription  \
# 0  2022091104    3662  (12:51) (Shotgun) J.Hurts pass incomplete shor...
# 1  2022091109    1772  (2:00) (Shotgun) C.Wentz pass short left to A....
# 2  2022091103    4199  (8:37) (Shotgun) M.Trubisky pass incomplete de...
# 3  2022091113    1812  (:29) (Shotgun) T.Brady pass incomplete short ...
# 5  2022091103    3505  (2:06) (Shotgun) J.Burrow pass incomplete shor...
#
#    quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 0        4     3         12            PHI           DET          PHI
# 1        2     3          1            WAS           JAX          WAS
# 2        5     3          3            PIT           CIN          PIT
# 3        2     2         10             TB           DAL          DAL
# 5        4     2          3            CIN           PIT          PIT
#
#    yardlineNumber  ... visitorTeamWinProbilityAdded  expectedPointsAdded  \
# 0              35  ...                    -0.012361            -1.161621
# 1              36  ...                    -0.025760             1.715613
# 2              32  ...                    -0.091500            -1.382778
# 3              29  ...                    -0.005521            -0.429005
# 5               3  ...                     0.137696            -0.991084
#
#    isDropback pff_runConceptPrimary  pff_runConceptSecondary  \
# 0        True                   NaN                      NaN
# 1        True                   NaN                      NaN
# 2        True                   NaN                      NaN
# 3        True                   NaN                      NaN
# 5        True                   NaN                      NaN
#
#    pff_runPassOption  pff_passCoverage  pff_manZone playType   target
# 0                  0           Cover-0          Man     pass  53439.0
# 1                  0           Cover-1          Man     pass  52474.0
# 2                  0           Cover-1          Man     pass  52457.0
# 3                  0           Cover-1          Man     pass  42033.0
# 5                  0           Cover-0          Man     pass  53434.0
#
# [5 rows x 52 columns]
